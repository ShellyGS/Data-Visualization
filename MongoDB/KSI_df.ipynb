# %%
# Importing dependencies
import pandas as pd
import numpy as np

# %%
# Reading KSI data into Pandas DF
KSI_df1 = pd.read_csv('Data/KSI.csv')
KSI_df1.head()
# Out:
#               X             Y    INDEX_  ACCNUM  YEAR                    DATE  \
# 0 -8.839173e+06  5.417681e+06  80908002     NaN  2017  2017/08/28 04:00:00+00
# 1 -8.839173e+06  5.417681e+06  80908003     NaN  2017  2017/08/28 04:00:00+00
# 2 -8.841470e+06  5.412741e+06  80888101     NaN  2017  2017/08/28 04:00:00+00
# 3 -8.841470e+06  5.412741e+06  80888102     NaN  2017  2017/08/28 04:00:00+00
# 4 -8.860274e+06  5.415493e+06  80942741     NaN  2017  2017/08/28 04:00:00+00
#
#    TIME           STREET1         STREET2         OFFSET  ... AG_DRIV  \
# 0  1135  215 LONSDALE  RD             NaN   51 m West of  ...     Yes
# 1  1135  215 LONSDALE  RD             NaN   51 m West of  ...     Yes
# 2  1845    OSSINGTON  AVE      HARBORD ST  30 m North of  ...     NaN
# 3  1845    OSSINGTON  AVE      HARBORD ST  30 m North of  ...     NaN
# 4  2010       RENFORTH DR  SILVER DART DR   3 m South of  ...     Yes
#
# ...

# %%
# Summary of dataset
KSI_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4956 entries, 0 to 4955
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  4956 non-null   float64
#  1   Y                  4956 non-null   float64
#  2   INDEX_             4956 non-null   int64
#  3   ACCNUM             1965 non-null   float64
#  4   YEAR               4956 non-null   int64
#  5   DATE               4956 non-null   object
#  6   TIME               4956 non-null   int64
#  7   STREET1            4956 non-null   object
#  8   STREET2            4441 non-null   object
#  9   OFFSET             2345 non-null   object
#  10  ROAD_CLASS         4916 non-null   object
#  11  DISTRICT           4860 non-null   object
#  12  WARDNUM            4094 non-null   float64
#  13  LATITUDE           4956 non-null   float64
#  14  LONGITUDE          4956 non-null   float64
#  15  LOCCOORD           4951 non-null   object
# ...

# %%
KSI_df2 = KSI_df1[KSI_df1.DISTRICT.notnull()]

# %%
KSI_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4860 entries, 0 to 4955
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  4860 non-null   float64
#  1   Y                  4860 non-null   float64
#  2   INDEX_             4860 non-null   int64
#  3   ACCNUM             1876 non-null   float64
#  4   YEAR               4860 non-null   int64
#  5   DATE               4860 non-null   object
#  6   TIME               4860 non-null   int64
#  7   STREET1            4860 non-null   object
#  8   STREET2            4355 non-null   object
#  9   OFFSET             2284 non-null   object
#  10  ROAD_CLASS         4836 non-null   object
#  11  DISTRICT           4860 non-null   object
#  12  WARDNUM            4076 non-null   float64
#  13  LATITUDE           4860 non-null   float64
#  14  LONGITUDE          4860 non-null   float64
#  15  LOCCOORD           4860 non-null   object
# ...

# %%
districts = KSI_df2['DISTRICT'].unique()

print (f'Districts:\n\n{districts}\n')
# Out:
# Districts:
#
# ['Toronto and East York' 'Etobicoke York' 'North York' 'Scarborough'
#  'Toronto East York']

# %%
KSI_df2 = KSI_df2.replace({"DISTRICT": "Toronto East York"}, {"DISTRICT": "Toronto and East York"})

# %%
districts = KSI_df2['DISTRICT'].unique()

print (f'Districts:\n\n{districts}\n')
# Out:
# Districts:
#
# ['Toronto and East York' 'Etobicoke York' 'North York' 'Scarborough']

# %%
d_ids = np.arange(1, 5)

print(f'District IDs:\n\n{d_ids}\n')
# Out:
# District IDs:
#
# [1 2 3 4]

# %%
district_ids = ['district' + str(id) for id in d_ids]

print(f'District IDs:\n\n{district_ids}\n')
# Out:
# District IDs:
#
# ['district1', 'district2', 'district3', 'district4']

# %%
district_df = pd.DataFrame({'district_id': district_ids, 'DISTRICT': districts})

# %%
district_df
# Out:
#   district_id               DISTRICT
# 0   district1  Toronto and East York
# 1   district2         Etobicoke York
# 2   district3             North York
# 3   district4            Scarborough

# %%
district_df.to_csv("Data/districts.csv", encoding='utf-8', index=False)

# %%
TPS_div = KSI_df2['DIVISION'].unique()

print (f'TPS Divisions:\n\n{TPS_div}\n')
# Out:
# TPS Divisions:
#
# ['D53' 'D14' 'D23' 'D52' 'D32' 'D42' 'D55' 'D51' 'D41' 'D12' 'D13' 'D31'
#  'D22' 'D43' 'D33' 'D11' 'NSA']

# %%
TPS_ids = np.arange(1, 18)

div_ids = ['div' + str(id) for id in TPS_ids]

print(f'TPS Division IDs:\n\n{div_ids}\n')
# Out:
# TPS Division IDs:
#
# ['div1', 'div2', 'div3', 'div4', 'div5', 'div6', 'div7', 'div8', 'div9', 'div10', 'div11', 'div12', 'div13', 'div14', 'div15', 'div16', 'div17']

# %%
division_df = pd.DataFrame({'division_id': div_ids, 'DIVISION': TPS_div})

# %%
division_df
# Out:
#    division_id DIVISION
# 0         div1      D53
# 1         div2      D14
# 2         div3      D23
# 3         div4      D52
# 4         div5      D32
# 5         div6      D42
# 6         div7      D55
# 7         div8      D51
# 8         div9      D41
# 9        div10      D12
# 10       div11      D13
# 11       div12      D31
# 12       div13      D22
# 13       div14      D43
# 14       div15      D33
# 15       div16      D11
# 16       div17      NSA

# %%
division_df.to_csv("Data/divisions.csv", encoding='utf8', index=False)

# %%
KSI_df2 = KSI_df2.replace({"AUTOMOBILE": "Yes"}, {"AUTOMOBILE": "True"})

# %%
KSI_df2["AUTOMOBILE"].fillna("False", inplace = True)

# %%
KSI_auto = KSI_df2['AUTOMOBILE'].unique()

print (f'Test:\n\n{KSI_auto}\n')
# Out:
# Test:
#
# ['True' 'False']

# %%
KSI_df2 = KSI_df2.replace({"ALCOHOL": "Yes"}, {"ALCOHOL": "True"})
KSI_df2["ALCOHOL"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"DISABILITY": "Yes"}, {"DISABILITY": "True"})
KSI_df2["DISABILITY"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"SPEEDING": "Yes"}, {"SPEEDING": "True"})
KSI_df2["SPEEDING"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"REDLIGHT": "Yes"}, {"REDLIGHT": "True"})
KSI_df2["REDLIGHT"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"TRUCK": "Yes"}, {"TRUCK": "True"})
KSI_df2["TRUCK"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"MOTORCYCLE": "Yes"}, {"MOTORCYCLE": "True"})
KSI_df2["MOTORCYCLE"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"CYCLIST": "Yes"}, {"CYCLIST": "True"})
KSI_df2["CYCLIST"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"PEDESTRIAN": "Yes"}, {"PEDESTRIAN": "True"})
KSI_df2["PEDESTRIAN"].fillna("False", inplace = True)

# %%
KSI_df2 = KSI_df2.replace({"PASSENGER": "Yes"}, {"PASSENGER": "True"})
KSI_df2["PASSENGER"].fillna("False", inplace = True)

# %%
KSI_df2["ROAD_CLASS"].fillna("Other", inplace = True)

# %%
KSI_df2["TRAFFCTL"].fillna("Other", inplace = True)

# %%
KSI_df2["VISIBILITY"].fillna("Other", inplace = True)

# %%
KSI_df2["RDSFCOND"].fillna("Other", inplace = True)

# %%
KSI_df2["ACCLASS"].fillna("Other", inplace = True)

# %%
KSI_df2["IMPACTYPE"].fillna("Other", inplace = True)

# %%
KSI_df2["INVTYPE"].fillna("Other", inplace = True)

# %%
KSI_df2["INJURY"].fillna("Other", inplace = True)

# %%
KSI_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4860 entries, 0 to 4955
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  4860 non-null   float64
#  1   Y                  4860 non-null   float64
#  2   INDEX_             4860 non-null   int64
#  3   ACCNUM             1876 non-null   float64
#  4   YEAR               4860 non-null   int64
#  5   DATE               4860 non-null   object
#  6   TIME               4860 non-null   int64
#  7   STREET1            4860 non-null   object
#  8   STREET2            4355 non-null   object
#  9   OFFSET             2284 non-null   object
#  10  ROAD_CLASS         4860 non-null   object
#  11  DISTRICT           4860 non-null   object
#  12  WARDNUM            4076 non-null   float64
#  13  LATITUDE           4860 non-null   float64
#  14  LONGITUDE          4860 non-null   float64
#  15  LOCCOORD           4860 non-null   object
# ...

# %%
KSI_df3 = KSI_df2[["YEAR", "DATE", "TIME", "STREET1", "ROAD_CLASS", "DISTRICT", "LATITUDE", "LONGITUDE", "LOCCOORD",
                   "ACCLOC", "TRAFFCTL", "VISIBILITY", "LIGHT", "RDSFCOND", "ACCLASS", "IMPACTYPE", "INVTYPE", 
                   "INVAGE", "INJURY", "PEDESTRIAN", "CYCLIST", "AUTOMOBILE", "MOTORCYCLE", "TRUCK", "PASSENGER",
                   "SPEEDING", "REDLIGHT", "ALCOHOL", "DISABILITY", "DIVISION", "ObjectId"]]

# %%
KSI_df3.head()
# Out:
#    YEAR                    DATE  TIME           STREET1      ROAD_CLASS  \
# 0  2017  2017/08/28 04:00:00+00  1135  215 LONSDALE  RD  Minor Arterial
# 1  2017  2017/08/28 04:00:00+00  1135  215 LONSDALE  RD  Minor Arterial
# 2  2017  2017/08/28 04:00:00+00  1845    OSSINGTON  AVE  Minor Arterial
# 3  2017  2017/08/28 04:00:00+00  1845    OSSINGTON  AVE  Minor Arterial
# 4  2017  2017/08/28 04:00:00+00  2010       RENFORTH DR  Major Arterial
#
#                 DISTRICT   LATITUDE  LONGITUDE      LOCCOORD  \
# 0  Toronto and East York  43.690566 -79.403644     Mid-Block
# 1  Toronto and East York  43.690566 -79.403644     Mid-Block
# 2  Toronto and East York  43.658473 -79.424274  Intersection
# 3  Toronto and East York  43.658473 -79.424274  Intersection
# 4         Etobicoke York  43.676356 -79.593196  Intersection
#
#                  ACCLOC  ... AUTOMOBILE MOTORCYCLE  TRUCK PASSENGER SPEEDING  \
# 0      Non Intersection  ...       True       True  False     False    False
# ...

# %%
KSI_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4860 entries, 0 to 4955
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   YEAR        4860 non-null   int64
#  1   DATE        4860 non-null   object
#  2   TIME        4860 non-null   int64
#  3   STREET1     4860 non-null   object
#  4   ROAD_CLASS  4860 non-null   object
#  5   DISTRICT    4860 non-null   object
#  6   LATITUDE    4860 non-null   float64
#  7   LONGITUDE   4860 non-null   float64
#  8   LOCCOORD    4860 non-null   object
#  9   ACCLOC      4860 non-null   object
#  10  TRAFFCTL    4860 non-null   object
#  11  VISIBILITY  4860 non-null   object
#  12  LIGHT       4860 non-null   object
#  13  RDSFCOND    4860 non-null   object
#  14  ACCLASS     4860 non-null   object
#  15  IMPACTYPE   4860 non-null   object
#  16  INVTYPE     4860 non-null   object
#  17  INVAGE      4860 non-null   object
#  18  INJURY      4860 non-null   object
# ...

# %%
KSI_df3["DATE2"] = KSI_df3["DATE"].str.extract(r'(\d+.\d+.\d+)')
# Out:
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_11629/588879035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KSI_df3["DATE2"] = KSI_df3["DATE"].str.extract(r'(\d+.\d+.\d+)')

# %%
KSI_df3["DATE"] = KSI_df3["DATE2"]
# Out:
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_11629/1529834621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KSI_df3["DATE"] = KSI_df3["DATE2"]

# %%
KSI_df3.head()
# Out:
#    YEAR        DATE  TIME           STREET1      ROAD_CLASS  \
# 0  2017  2017/08/28  1135  215 LONSDALE  RD  Minor Arterial
# 1  2017  2017/08/28  1135  215 LONSDALE  RD  Minor Arterial
# 2  2017  2017/08/28  1845    OSSINGTON  AVE  Minor Arterial
# 3  2017  2017/08/28  1845    OSSINGTON  AVE  Minor Arterial
# 4  2017  2017/08/28  2010       RENFORTH DR  Major Arterial
#
#                 DISTRICT   LATITUDE  LONGITUDE      LOCCOORD  \
# 0  Toronto and East York  43.690566 -79.403644     Mid-Block
# 1  Toronto and East York  43.690566 -79.403644     Mid-Block
# 2  Toronto and East York  43.658473 -79.424274  Intersection
# 3  Toronto and East York  43.658473 -79.424274  Intersection
# 4         Etobicoke York  43.676356 -79.593196  Intersection
#
#                  ACCLOC  ... MOTORCYCLE  TRUCK PASSENGER SPEEDING REDLIGHT  \
# 0      Non Intersection  ...       True  False     False    False    False
# 1      Non Intersection  ...       True  False     False    False    False
# ...

# %%
del KSI_df3["DATE2"]

# %%
cleaned_KSI = KSI_df3.rename(columns={"ObjectId": "Record_ID"})

# %%
cleaned_KSI.head()
# Out:
#    YEAR        DATE  TIME           STREET1      ROAD_CLASS  \
# 0  2017  2017/08/28  1135  215 LONSDALE  RD  Minor Arterial
# 1  2017  2017/08/28  1135  215 LONSDALE  RD  Minor Arterial
# 2  2017  2017/08/28  1845    OSSINGTON  AVE  Minor Arterial
# 3  2017  2017/08/28  1845    OSSINGTON  AVE  Minor Arterial
# 4  2017  2017/08/28  2010       RENFORTH DR  Major Arterial
#
#                 DISTRICT   LATITUDE  LONGITUDE      LOCCOORD  \
# 0  Toronto and East York  43.690566 -79.403644     Mid-Block
# 1  Toronto and East York  43.690566 -79.403644     Mid-Block
# 2  Toronto and East York  43.658473 -79.424274  Intersection
# 3  Toronto and East York  43.658473 -79.424274  Intersection
# 4         Etobicoke York  43.676356 -79.593196  Intersection
#
#                  ACCLOC  ... AUTOMOBILE MOTORCYCLE  TRUCK PASSENGER SPEEDING  \
# 0      Non Intersection  ...       True       True  False     False    False
# 1      Non Intersection  ...       True       True  False     False    False
# ...

# %%
cleaned_KSI.to_csv("Data/KSI_cleaned.csv", encoding='utf8', index=False)

# %%
merged_df = cleaned_KSI.merge(division_df, on='DIVISION')
merged_KSI = merged_df.merge(district_df, on='DISTRICT')

merged_KSI.head()
# Out:
#    YEAR        DATE  TIME           STREET1      ROAD_CLASS  \
# 0  2017  2017/08/28  1135  215 LONSDALE  RD  Minor Arterial
# 1  2017  2017/08/28  1135  215 LONSDALE  RD  Minor Arterial
# 2  2017  2017/09/05  1735       MILLWOOD RD           Local
# 3  2017  2017/09/05  1735       MILLWOOD RD           Local
# 4  2017  2017/09/05  1735       MILLWOOD RD           Local
#
#                 DISTRICT   LATITUDE  LONGITUDE   LOCCOORD            ACCLOC  \
# 0  Toronto and East York  43.690566 -79.403644  Mid-Block  Non Intersection
# 1  Toronto and East York  43.690566 -79.403644  Mid-Block  Non Intersection
# 2  Toronto and East York  43.699900 -79.393703  Mid-Block  Non Intersection
# 3  Toronto and East York  43.699900 -79.393703  Mid-Block  Non Intersection
# 4  Toronto and East York  43.699900 -79.393703  Mid-Block  Non Intersection
#
#    ...  TRUCK PASSENGER SPEEDING REDLIGHT ALCOHOL DISABILITY DIVISION  \
# 0  ...  False     False    False    False   False      False      D53
# ...

# %%
merged_KSI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4860 entries, 0 to 4859
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR         4860 non-null   int64
#  1   DATE         4860 non-null   object
#  2   TIME         4860 non-null   int64
#  3   STREET1      4860 non-null   object
#  4   ROAD_CLASS   4860 non-null   object
#  5   DISTRICT     4860 non-null   object
#  6   LATITUDE     4860 non-null   float64
#  7   LONGITUDE    4860 non-null   float64
#  8   LOCCOORD     4860 non-null   object
#  9   ACCLOC       4860 non-null   object
#  10  TRAFFCTL     4860 non-null   object
#  11  VISIBILITY   4860 non-null   object
#  12  LIGHT        4860 non-null   object
#  13  RDSFCOND     4860 non-null   object
#  14  ACCLASS      4860 non-null   object
#  15  IMPACTYPE    4860 non-null   object
#  16  INVTYPE      4860 non-null   object
#  17  INVAGE       4860 non-null   object
# ...

# %%
KSI_final = merged_KSI.drop(columns = ['DIVISION', 'DISTRICT'])

KSI_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4860 entries, 0 to 4859
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR         4860 non-null   int64
#  1   DATE         4860 non-null   object
#  2   TIME         4860 non-null   int64
#  3   STREET1      4860 non-null   object
#  4   ROAD_CLASS   4860 non-null   object
#  5   LATITUDE     4860 non-null   float64
#  6   LONGITUDE    4860 non-null   float64
#  7   LOCCOORD     4860 non-null   object
#  8   ACCLOC       4860 non-null   object
#  9   TRAFFCTL     4860 non-null   object
#  10  VISIBILITY   4860 non-null   object
#  11  LIGHT        4860 non-null   object
#  12  RDSFCOND     4860 non-null   object
#  13  ACCLASS      4860 non-null   object
#  14  IMPACTYPE    4860 non-null   object
#  15  INVTYPE      4860 non-null   object
#  16  INVAGE       4860 non-null   object
#  17  INJURY       4860 non-null   object
# ...

# %%
KSI_final.to_csv("Data/KSI_final.csv", encoding='utf8', index=False)
